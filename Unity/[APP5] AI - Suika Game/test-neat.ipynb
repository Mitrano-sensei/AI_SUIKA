# %%
import neat
import numpy as np
import random
from mlagents_envs.environment import UnityEnvironment




# Définir une fonction d'évaluation (fitness function) pour évaluer les performances des individus
def eval_genomes(genomes, config):
    global ge, nets;
    env.reset()
    env.step()
    done = False
    tracked_agent = -1
    ge=[]
    nets=[]
    for genome_id, genome in genomes:
        genome.fitness = 0
        ge.append(genome)
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        nets.append(net)
        
        # Votre logique d'évaluation ici

    while not done:
       
        for i in range(0,len(list(env.behavior_specs.keys()))):
            decision_steps, terminal_steps = env.get_steps(list(env.behavior_specs.keys())[i])
            

            if (i == 0): # Tracking steps for first agent only
                if tracked_agent == -1 and len(decision_steps) >= 1:
                    tracked_agent = decision_steps.agent_id[0]
                if tracked_agent in terminal_steps:
                   done = True
                   break

            ge[i].fitness=decision_steps.reward[0]+ge[i].fitness
            # print(list(env.behavior_specs.keys())[i])
            spec = env.behavior_specs[list(env.behavior_specs.keys())[i]]
            

            output = nets[i].activate(decision_steps.obs[0][0])
            # print(output)

            # Récupérer les observations des agents pour un comportement spécifique
            pos=np.array([[(output[0]+1)/2]]) # TODO : Change that
            # onJoue=np.array([[random.random() > .5]])
            onJoue=np.array([[output[1]>0]])
            
            

            creationAction(pos,onJoue,spec, i)
            # print(decision_steps.reward[0])
            
        env.step()
    # for i in range (0,len(ge)):
    #     for j in range (0,10+1):
    #         #Il faut récupérer les inputs
    #         #Faut réussir à appeler la fonction CollectObservations du GameManager

    #         #Il mettre les input dans le réseau de neuronnes
    #         output = nets[i].activate() #Prend en param les inputs

    #         #Lance l'action voulu par l'output 
    #         #On doit réussir à lancer la fonction OnActionReceived du gameManager


    #         #On récupère Reward et on met à jour fitness


        

def run(path="config.txt"):
    # Charger la configuration par défaut de NEAT
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                        neat.DefaultSpeciesSet, neat.DefaultStagnation,
                        path)  # Vous pouvez spécifier un fichier de configuration personnalisé

    # Créer une population initiale
    p = neat.Population(config)

    # Ajouter des rapports pour afficher des statistiques pendant l'évolution
    p.add_reporter(neat.StdOutReporter(True))  # Affiche des statistiques dans la console
    p.add_reporter(neat.StatisticsReporter())   # Collecte des statistiques sur la population

    # Évaluer la population sur 10 générations
    winner = p.run(eval_genomes, 100)

    # Utiliser le gagnant (meilleur individu) pour votre tâche spécifique


def creationAction(pos,onJoue,spec, id):
    action=spec.action_spec.empty_action(1)
    action.add_continuous(pos)

    action.add_discrete(onJoue)
    env.set_actions(list(env.behavior_specs.keys())[id], action)


try:
    env.close()
except:
    pass

env = UnityEnvironment(file_name="./build/SuikaAI",worker_id=1)
run(path="config.txt")
env.close()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 12.50000 stdev: 12.50000
# Best fitness: 25.00000 - size: (2, 404) - species 1 - id 1
# Average adjusted fitness: 0.500
# Mean genetic distance 1.258, standard deviation 0.566
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     4     25.0    0.500     0
# Total extinctions: 0
# Generation time: 1.571 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 118.75000 stdev: 20.72890
# Best fitness: 150.00000 - size: (2, 403) - species 1 - id 6
# Average adjusted fitness: 0.375
# Mean genetic distance 1.091, standard deviation 0.329
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     4    150.0    0.375     0
# Total extinctions: 0
# Generation time: 1.827 sec (1.699 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 170.25000 stdev: 23.02580
# Best fitness: 206.00000 - size: (2, 404) - species 1 - id 2
# Average adjusted fitness: 0.362
# Mean genetic distance 0.972, standard deviation 0.328
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     4    206.0    0.362     0
# Total extinctions: 0
# Generation time: 2.711 sec (2.036 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 239.25000 stdev: 15.84890
# Best fitness: 266.00000 - size: (3, 401) - species 1 - id 10
# Average adjusted fitness: 0.348
# Mean genetic distance 0.985, standard deviation 0.238
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     4    266.0    0.348     0
# Total extinctions: 0
# Generation time: 3.316 sec (2.356 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 321.75000 stdev: 46.97539
# Best fitness: 381.00000 - size: (2, 404) - species 1 - id 2
# Average adjusted fitness: 0.537
# Mean genetic distance 0.631, standard deviation 0.346
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     4    381.0    0.537     0
# Total extinctions: 0
# Generation time: 4.230 sec (2.731 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 335.25000 stdev: 194.60136
# Best fitness: 478.00000 - size: (3, 400) - species 1 - id 11
# Average adjusted fitness: 0.701
# Mean genetic distance 0.676, standard deviation 0.297
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     4    478.0    0.701     0
# Total extinctions: 0
# Generation time: 5.111 sec (3.128 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 627.25000 stdev: 117.12040
# Best fitness: 762.00000 - size: (3, 404) - species 1 - id 16
# Average adjusted fitness: 0.480
# Mean genetic distance 0.827, standard deviation 0.218
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     4    762.0    0.480     0
# Total extinctions: 0
# Generation time: 5.717 sec (3.498 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 661.50000 stdev: 51.48058
# Best fitness: 713.00000 - size: (3, 404) - species 1 - id 16
# Average adjusted fitness: 0.624
# Mean genetic distance 1.026, standard deviation 0.430
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     4    713.0    0.624     1
# Total extinctions: 0
# Generation time: 6.628 sec (3.889 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 664.25000 stdev: 75.26412
# Best fitness: 757.00000 - size: (3, 399) - species 1 - id 20
# Average adjusted fitness: 0.473
# Mean genetic distance 0.724, standard deviation 0.349
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     4    757.0    0.473     2
# Total extinctions: 0
# Generation time: 7.511 sec (4.291 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 878.25000 stdev: 167.33406
# Best fitness: 1047.00000 - size: (3, 398) - species 1 - id 22
# Average adjusted fitness: 0.554
# Mean genetic distance 0.805, standard deviation 0.218
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     4   1047.0    0.554     0
# Total extinctions: 0
# Generation time: 8.133 sec (4.675 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 812.50000 stdev: 69.12489
# Best fitness: 925.00000 - size: (3, 398) - species 1 - id 22
# Average adjusted fitness: 0.402
# Mean genetic distance 0.873, standard deviation 0.423
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10     4    925.0    0.402     1
# Total extinctions: 0
# Generation time: 9.010 sec (5.419 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 882.25000 stdev: 92.35089
# Best fitness: 1013.00000 - size: (4, 393) - species 1 - id 26
# Average adjusted fitness: 0.497
# Mean genetic distance 0.739, standard deviation 0.215
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11     4   1013.0    0.497     2
# Total extinctions: 0
# Generation time: 9.927 sec (6.229 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 852.50000 stdev: 30.92329
# Best fitness: 900.00000 - size: (4, 393) - species 1 - id 27
# Average adjusted fitness: 0.367
# Mean genetic distance 0.709, standard deviation 0.209
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12     4    900.0    0.367     3
# Total extinctions: 0
# Generation time: 10.514 sec (7.010 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 692.25000 stdev: 710.37679
# Best fitness: 1610.00000 - size: (4, 393) - species 1 - id 27
# Average adjusted fitness: 0.430
# Mean genetic distance 0.876, standard deviation 0.221
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13     4   1610.0    0.430     0
# Total extinctions: 0
# Generation time: 11.426 sec (7.821 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 1364.00000 stdev: 293.99660
# Best fitness: 1698.00000 - size: (4, 393) - species 1 - id 27
# Average adjusted fitness: 0.544
# Mean genetic distance 0.501, standard deviation 0.280
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14     4   1698.0    0.544     0
# Total extinctions: 0
# Generation time: 12.309 sec (8.629 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 1582.75000 stdev: 322.85552
# Best fitness: 1806.00000 - size: (4, 391) - species 1 - id 29
# Average adjusted fitness: 0.714
# Mean genetic distance 0.791, standard deviation 0.139
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     4   1806.0    0.714     0
# Total extinctions: 0
# Generation time: 12.928 sec (9.410 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 1494.25000 stdev: 326.03863
# Best fitness: 1897.00000 - size: (5, 390) - species 1 - id 36
# Average adjusted fitness: 0.462
# Mean genetic distance 0.811, standard deviation 0.177
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     4   1897.0    0.462     0
# Total extinctions: 0
# Generation time: 13.824 sec (10.221 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 1433.75000 stdev: 352.99248
# Best fitness: 2041.00000 - size: (5, 390) - species 1 - id 36
# Average adjusted fitness: 0.299
# Mean genetic distance 0.556, standard deviation 0.281
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     4   2041.0    0.299     0
# Total extinctions: 0
# Generation time: 14.708 sec (11.029 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 1970.75000 stdev: 501.27007
# Best fitness: 2600.00000 - size: (5, 390) - species 1 - id 36
# Average adjusted fitness: 0.439
# Mean genetic distance 0.744, standard deviation 0.127
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     4   2600.0    0.439     0
# Total extinctions: 0
# Generation time: 15.331 sec (11.811 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 1512.25000 stdev: 187.89808
# Best fitness: 1817.00000 - size: (5, 390) - species 1 - id 36
# Average adjusted fitness: 0.407
# Mean genetic distance 0.630, standard deviation 0.284
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     4   1817.0    0.407     1
# Total extinctions: 0
# Generation time: 16.219 sec (12.620 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 1736.25000 stdev: 378.98244
# Best fitness: 2369.00000 - size: (6, 387) - species 1 - id 43
# Average adjusted fitness: 0.353
# Mean genetic distance 0.938, standard deviation 0.242
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     4   2369.0    0.353     2
# Total extinctions: 0
# Generation time: 17.124 sec (13.431 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 1988.50000 stdev: 427.63916
# Best fitness: 2457.00000 - size: (4, 384) - species 1 - id 46
# Average adjusted fitness: 0.494
# Mean genetic distance 0.749, standard deviation 0.403
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     4   2457.0    0.494     3
# Total extinctions: 0
# Generation time: 17.705 sec (14.209 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 2185.50000 stdev: 604.53887
# Best fitness: 2825.00000 - size: (6, 384) - species 1 - id 48
# Average adjusted fitness: 0.488
# Mean genetic distance 0.866, standard deviation 0.340
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     4   2825.0    0.488     0
# Total extinctions: 0
# Generation time: 18.626 sec (15.020 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 1212.75000 stdev: 701.18485
# Best fitness: 1669.00000 - size: (6, 384) - species 1 - id 48
# Average adjusted fitness: 0.727
# Mean genetic distance 0.469, standard deviation 0.272
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     4   1669.0    0.727     1
# Total extinctions: 0
# Generation time: 19.521 sec (15.829 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 1881.25000 stdev: 370.53365
# Best fitness: 2516.00000 - size: (5, 381) - species 1 - id 52
# Average adjusted fitness: 0.288
# Mean genetic distance 0.758, standard deviation 0.299
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     4   2516.0    0.288     2
# Total extinctions: 0
# Generation time: 20.122 sec (16.611 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 2063.25000 stdev: 524.76108
# Best fitness: 2972.00000 - size: (5, 381) - species 1 - id 52
# Average adjusted fitness: 0.258
# Mean genetic distance 0.858, standard deviation 0.289
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25     4   2972.0    0.258     0
# Total extinctions: 0
# Generation time: 21.024 sec (17.420 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 1823.00000 stdev: 1194.01361
# Best fitness: 3325.00000 - size: (6, 381) - species 1 - id 53
# Average adjusted fitness: 0.548
# Mean genetic distance 0.511, standard deviation 0.214
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26     4   3325.0    0.548     0
# Total extinctions: 0
# Generation time: 21.922 sec (18.230 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 1929.25000 stdev: 122.50791
# Best fitness: 2138.00000 - size: (6, 381) - species 1 - id 58
# Average adjusted fitness: 0.333
# Mean genetic distance 0.579, standard deviation 0.102
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27     4   2138.0    0.333     1
# Total extinctions: 0
# Generation time: 22.519 sec (19.011 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 2351.75000 stdev: 678.57843
# Best fitness: 3525.00000 - size: (6, 381) - species 1 - id 53
# Average adjusted fitness: 0.271
# Mean genetic distance 0.456, standard deviation 0.196
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28     4   3525.0    0.271     0
# Total extinctions: 0
# Generation time: 23.418 sec (19.820 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 496.25000 stdev: 859.53021
# Best fitness: 1985.00000 - size: (6, 381) - species 1 - id 53
# Average adjusted fitness: 0.250
# Mean genetic distance 0.496, standard deviation 0.203
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29     4   1985.0    0.250     1
# Total extinctions: 0
# Generation time: 24.322 sec (20.630 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 2030.75000 stdev: 5.84701
# Best fitness: 2038.00000 - size: (6, 374) - species 1 - id 63
# Average adjusted fitness: 0.442
# Mean genetic distance 0.624, standard deviation 0.300
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30     4   2038.0    0.442     2
# Total extinctions: 0
# Generation time: 24.918 sec (21.410 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 2972.25000 stdev: 853.21081
# Best fitness: 3975.00000 - size: (6, 372) - species 1 - id 66
# Average adjusted fitness: 0.465
# Mean genetic distance 0.674, standard deviation 0.255
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31     4   3975.0    0.465     0
# Total extinctions: 0
# Generation time: 25.820 sec (22.221 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 2153.25000 stdev: 1479.10165
# Best fitness: 4178.00000 - size: (6, 370) - species 1 - id 67
# Average adjusted fitness: 0.515
# Mean genetic distance 0.694, standard deviation 0.257
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     4   4178.0    0.515     0
# Total extinctions: 0
# Generation time: 26.722 sec (23.031 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 2786.00000 stdev: 634.39775
# Best fitness: 3774.00000 - size: (6, 372) - species 1 - id 66
# Average adjusted fitness: 0.362
# Mean genetic distance 0.847, standard deviation 0.355
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     4   3774.0    0.362     1
# Total extinctions: 0
# Generation time: 27.317 sec (23.810 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 3821.25000 stdev: 1668.17196
# Best fitness: 6375.00000 - size: (8, 367) - species 1 - id 71
# Average adjusted fitness: 0.372
# Mean genetic distance 0.984, standard deviation 0.230
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     4   6375.0    0.372     0
# Total extinctions: 0
# Generation time: 28.217 sec (24.620 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 2351.75000 stdev: 1571.67083
# Best fitness: 4428.00000 - size: (7, 367) - species 1 - id 72
# Average adjusted fitness: 0.531
# Mean genetic distance 0.632, standard deviation 0.296
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35     4   4428.0    0.531     1
# Total extinctions: 0
# Generation time: 29.116 sec (25.429 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 3491.75000 stdev: 883.79279
# Best fitness: 4454.00000 - size: (7, 365) - species 1 - id 76
# Average adjusted fitness: 0.495
# Mean genetic distance 0.727, standard deviation 0.143
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     4   4454.0    0.495     2
# Total extinctions: 0
# Generation time: 29.718 sec (26.209 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 2812.00000 stdev: 2074.73516
# Best fitness: 5850.00000 - size: (6, 362) - species 1 - id 74
# Average adjusted fitness: 0.481
# Mean genetic distance 0.639, standard deviation 0.290
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     4   5850.0    0.481     3
# Total extinctions: 0
# Generation time: 30.615 sec (27.018 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 3253.25000 stdev: 1120.41831
# Best fitness: 5193.00000 - size: (8, 362) - species 1 - id 80
# Average adjusted fitness: 0.261
# Mean genetic distance 0.867, standard deviation 0.192
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     4   5193.0    0.261     4
# Total extinctions: 0
# Generation time: 31.874 sec (27.864 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 3459.25000 stdev: 865.99116
# Best fitness: 4868.00000 - size: (8, 362) - species 1 - id 80
# Average adjusted fitness: 0.340
# Mean genetic distance 0.671, standard deviation 0.335
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     4   4868.0    0.340     5
# Total extinctions: 0
# Generation time: 31.794 sec (28.611 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 3752.00000 stdev: 894.43418
# Best fitness: 4668.00000 - size: (8, 362) - species 1 - id 80
# Average adjusted fitness: 0.535
# Mean genetic distance 0.764, standard deviation 0.463
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40     4   4668.0    0.535     6
# Total extinctions: 0
# Generation time: 33.015 sec (29.421 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 4749.50000 stdev: 1481.56007
# Best fitness: 6881.00000 - size: (8, 361) - species 1 - id 86
# Average adjusted fitness: 0.481
# Mean genetic distance 0.951, standard deviation 0.281
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     4   6881.0    0.481     0
# Total extinctions: 0
# Generation time: 33.917 sec (30.230 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 5026.00000 stdev: 87.53571
# Best fitness: 5166.00000 - size: (6, 360) - species 1 - id 88
# Average adjusted fitness: 0.404
# Mean genetic distance 1.064, standard deviation 0.449
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     4   5166.0    0.404     1
# Total extinctions: 0
# Generation time: 34.532 sec (31.011 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 3859.25000 stdev: 1001.41359
# Best fitness: 5331.00000 - size: (8, 361) - species 1 - id 86
# Average adjusted fitness: 0.387
# Mean genetic distance 0.892, standard deviation 0.451
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     4   5331.0    0.387     2
# Total extinctions: 0
# Generation time: 35.410 sec (31.821 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 5443.25000 stdev: 244.44874
# Best fitness: 5854.00000 - size: (8, 361) - species 1 - id 86
# Average adjusted fitness: 0.317
# Mean genetic distance 1.137, standard deviation 0.537
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44     4   5854.0    0.317     3
# Total extinctions: 0
# Generation time: 36.332 sec (32.632 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 4527.00000 stdev: 2200.68046
# Best fitness: 8309.00000 - size: (8, 361) - species 1 - id 94
# Average adjusted fitness: 0.282
# Mean genetic distance 0.651, standard deviation 0.399
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45     4   8309.0    0.282     0
# Total extinctions: 0
# Generation time: 36.913 sec (33.412 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 5184.25000 stdev: 764.80173
# Best fitness: 6075.00000 - size: (8, 358) - species 1 - id 96
# Average adjusted fitness: 0.475
# Mean genetic distance 0.830, standard deviation 0.314
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46     4   6075.0    0.475     1
# Total extinctions: 0
# Generation time: 37.812 sec (34.221 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 4017.25000 stdev: 1046.49591
# Best fitness: 5794.00000 - size: (8, 358) - species 1 - id 97
# Average adjusted fitness: 0.302
# Mean genetic distance 0.858, standard deviation 0.197
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47     4   5794.0    0.302     2
# Total extinctions: 0
# Generation time: 38.729 sec (35.033 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 3324.50000 stdev: 181.24914
# Best fitness: 3638.00000 - size: (7, 351) - species 1 - id 100
# Average adjusted fitness: 0.269
# Mean genetic distance 0.893, standard deviation 0.390
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48     4   3638.0    0.269     3
# Total extinctions: 0
# Generation time: 39.345 sec (35.780 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 6473.00000 stdev: 2276.65676
# Best fitness: 9769.00000 - size: (7, 352) - species 1 - id 101
# Average adjusted fitness: 0.488
# Mean genetic distance 0.939, standard deviation 0.231
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49     4   9769.0    0.488     0
# Total extinctions: 0
# Generation time: 40.217 sec (36.622 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 1711.75000 stdev: 1711.90426
# Best fitness: 3456.00000 - size: (7, 352) - species 1 - id 101
# Average adjusted fitness: 0.495
# Mean genetic distance 0.862, standard deviation 0.260
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50     4   3456.0    0.495     1
# Total extinctions: 0
# Generation time: 41.100 sec (37.431 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 3590.25000 stdev: 109.29862
# Best fitness: 3752.00000 - size: (7, 349) - species 1 - id 105
# Average adjusted fitness: 0.475
# Mean genetic distance 0.994, standard deviation 0.282
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51     4   3752.0    0.475     2
# Total extinctions: 0
# Generation time: 41.730 sec (38.212 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 3171.75000 stdev: 2001.14734
# Best fitness: 5543.00000 - size: (7, 349) - species 1 - id 108
# Average adjusted fitness: 0.572
# Mean genetic distance 1.017, standard deviation 0.442
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52     4   5543.0    0.572     3
# Total extinctions: 0
# Generation time: 42.630 sec (39.022 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 3444.25000 stdev: 2245.25905
# Best fitness: 6285.00000 - size: (7, 349) - species 1 - id 108
# Average adjusted fitness: 0.548
# Mean genetic distance 1.045, standard deviation 0.245
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53     4   6285.0    0.548     4
# Total extinctions: 0
# Generation time: 43.504 sec (39.831 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 3505.75000 stdev: 2399.24346
# Best fitness: 6778.00000 - size: (7, 352) - species 1 - id 112
# Average adjusted fitness: 0.517
# Mean genetic distance 0.937, standard deviation 0.154
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54     4   6778.0    0.517     5
# Total extinctions: 0
# Generation time: 44.130 sec (40.611 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 6152.25000 stdev: 2613.48631
# Best fitness: 10169.00000 - size: (7, 352) - species 1 - id 112
# Average adjusted fitness: 0.369
# Mean genetic distance 0.844, standard deviation 0.370
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55     4  10169.0    0.369     0
# Total extinctions: 0
# Generation time: 45.021 sec (41.422 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 1922.00000 stdev: 1922.61918
# Best fitness: 3913.00000 - size: (8, 350) - species 1 - id 115
# Average adjusted fitness: 0.491
# Mean genetic distance 0.814, standard deviation 0.352
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56     4   3913.0    0.491     1
# Total extinctions: 0
# Generation time: 45.895 sec (42.230 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 1900.75000 stdev: 1900.75030
# Best fitness: 3803.00000 - size: (8, 348) - species 1 - id 117
# Average adjusted fitness: 0.500
# Mean genetic distance 0.870, standard deviation 0.269
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57     4   3803.0    0.500     2
# Total extinctions: 0
# Generation time: 46.527 sec (43.010 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 5724.25000 stdev: 2691.89026
# Best fitness: 10344.00000 - size: (8, 347) - species 1 - id 120
# Average adjusted fitness: 0.286
# Mean genetic distance 0.505, standard deviation 0.220
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58     4  10344.0    0.286     0
# Total extinctions: 0
# Generation time: 47.421 sec (43.818 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 2958.75000 stdev: 1708.28267
# Best fitness: 3960.00000 - size: (8, 347) - species 1 - id 120
# Average adjusted fitness: 0.747
# Mean genetic distance 0.408, standard deviation 0.169
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59     4   3960.0    0.747     1
# Total extinctions: 0
# Generation time: 48.324 sec (44.628 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 2673.50000 stdev: 2832.21543
# Best fitness: 6669.00000 - size: (9, 347) - species 1 - id 124
# Average adjusted fitness: 0.401
# Mean genetic distance 0.768, standard deviation 0.197
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60     4   6669.0    0.401     2
# Total extinctions: 0
# Generation time: 48.909 sec (45.409 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 5265.25000 stdev: 1287.10360
# Best fitness: 7460.00000 - size: (10, 350) - species 1 - id 126
# Average adjusted fitness: 0.326
# Mean genetic distance 1.111, standard deviation 0.180
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61     4   7460.0    0.326     3
# Total extinctions: 0
# Generation time: 49.825 sec (46.219 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 2993.00000 stdev: 3245.24067
# Best fitness: 7760.00000 - size: (9, 344) - species 1 - id 128
# Average adjusted fitness: 0.386
# Mean genetic distance 0.955, standard deviation 0.219
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62     4   7760.0    0.386     4
# Total extinctions: 0
# Generation time: 50.718 sec (47.028 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 2223.25000 stdev: 2228.76012
# Best fitness: 4668.00000 - size: (9, 349) - species 1 - id 125
# Average adjusted fitness: 0.476
# Mean genetic distance 1.168, standard deviation 0.244
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63     4   4668.0    0.476     5
# Total extinctions: 0
# Generation time: 51.323 sec (47.810 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 1075.00000 stdev: 1861.95462
# Best fitness: 4300.00000 - size: (9, 349) - species 1 - id 125
# Average adjusted fitness: 0.250
# Mean genetic distance 1.070, standard deviation 0.439
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64     4   4300.0    0.250     6
# Total extinctions: 0
# Generation time: 52.220 sec (48.618 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 2642.25000 stdev: 2723.62446
# Best fitness: 6219.00000 - size: (9, 349) - species 1 - id 125
# Average adjusted fitness: 0.425
# Mean genetic distance 0.987, standard deviation 0.408
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65     4   6219.0    0.425     7
# Total extinctions: 0
# Generation time: 53.122 sec (49.429 average)
#
#  ****** Running generation 66 ******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 108
#     105     pass
#     107 env = UnityEnvironment(file_name="./build/SuikaAI",worker_id=1)
# --> 108 run(path="config.txt")
#     109 env.close()
#
# Cell In[10], line 89, in run(path)
#      86 p.add_reporter(neat.StatisticsReporter())   # Collecte des statistiques sur la population
#      88 # Évaluer la population sur 10 générations
# ---> 89 winner = p.run(eval_genomes, 100)
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\neat\population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# Cell In[10], line 57, in eval_genomes(genomes, config)
#      54     creationAction(pos,onJoue,spec, i)
#      55     # print(decision_steps.reward[0])
# ---> 57 env.step()
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\environment.py:348, in UnityEnvironment.step(self)
#     346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
# --> 348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
#     350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\rpc_communicator.py:142, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     140 message.unity_input.CopyFrom(inputs)
#     141 self.unity_to_external.parent_conn.send(message)
# --> 142 self.poll_for_timeout(poll_callback)
#     143 output = self.unity_to_external.parent_conn.recv()
#     144 if output.header.status != 200:
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\rpc_communicator.py:106, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     104 callback_timeout_wait = self.timeout_wait // 10
#     105 while time.monotonic() < deadline:
# --> 106     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     107         # Got an acknowledgment from the connection
#     108         return
#     109     if poll_callback:
#     110         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File C:\Python310\lib\multiprocessing\connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File C:\Python310\lib\multiprocessing\connection.py:335, in PipeConnection._poll(self, timeout)
#     332 if (self._got_empty_message or
#     333             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     334     return True
# --> 335 return bool(wait([self], timeout))
#
# File C:\Python310\lib\multiprocessing\connection.py:884, in wait(object_list, timeout)
#     881                 ready_objects.add(o)
#     882                 timeout = 0
# --> 884     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     885 finally:
#     886     # request that overlapped reads stop
#     887     for ov in ov_list:
#
# File C:\Python310\lib\multiprocessing\connection.py:816, in _exhaustive_wait(handles, timeout)
#     814 ready = []
#     815 while L:
# --> 816     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     817     if res == WAIT_TIMEOUT:
#     818         break
#
# KeyboardInterrupt:

# %%
env.close()
