# %%
import neat
import numpy as np
import random
from mlagents_envs.environment import UnityEnvironment




# Définir une fonction d'évaluation (fitness function) pour évaluer les performances des individus
def eval_genomes(genomes, config):
    global ge, nets;
    env.reset()
    env.step()
    done = False
    tracked_agent = -1
    ge=[]
    nets=[]
    for genome_id, genome in genomes:
        genome.fitness = 0
        ge.append(genome)
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        nets.append(net)
        
        # Votre logique d'évaluation ici

    while not done:
       
        for i in range(0,len(list(env.behavior_specs.keys()))):
            decision_steps, terminal_steps = env.get_steps(list(env.behavior_specs.keys())[i])
            

            if (i == 0): # Tracking steps for first agent only
                if tracked_agent == -1 and len(decision_steps) >= 1:
                    tracked_agent = decision_steps.agent_id[0]
                if tracked_agent in terminal_steps:
                   done = True
                   break

            ge[i].fitness=decision_steps.reward[0]+ge[i].fitness
            # print(list(env.behavior_specs.keys())[i])
            spec = env.behavior_specs[list(env.behavior_specs.keys())[i]]
            

            output = nets[i].activate(decision_steps.obs[0][0])
            # print(output)

            # Récupérer les observations des agents pour un comportement spécifique
            pos=np.array([[(output[0])]]) 
            # onJoue=np.array([[random.random() > .5]])
            onJoue=np.array([[output[1]>0]])
            
            

            creationAction(pos,onJoue,spec, i)
            # print(decision_steps.reward[0])
            
        env.step()
    # for i in range (0,len(ge)):
    #     for j in range (0,10+1):
    #         #Il faut récupérer les inputs
    #         #Faut réussir à appeler la fonction CollectObservations du GameManager

    #         #Il mettre les input dans le réseau de neuronnes
    #         output = nets[i].activate() #Prend en param les inputs

    #         #Lance l'action voulu par l'output 
    #         #On doit réussir à lancer la fonction OnActionReceived du gameManager


    #         #On récupère Reward et on met à jour fitness


        

def run(path="config.txt"):
    # Charger la configuration par défaut de NEAT
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                        neat.DefaultSpeciesSet, neat.DefaultStagnation,
                        path)  # Vous pouvez spécifier un fichier de configuration personnalisé

    # Créer une population initiale
    p = neat.Population(config)

    # Ajouter des rapports pour afficher des statistiques pendant l'évolution
    p.add_reporter(neat.StdOutReporter(True))  # Affiche des statistiques dans la console
    p.add_reporter(neat.StatisticsReporter())   # Collecte des statistiques sur la population

    # Évaluer la population sur 10 générations
    winner = p.run(eval_genomes, 100)

    # Utiliser le gagnant (meilleur individu) pour votre tâche spécifique
    return winner;


def creationAction(pos,onJoue,spec, id):
    action=spec.action_spec.empty_action(1)
    action.add_continuous(pos)

    action.add_discrete(onJoue)
    env.set_actions(list(env.behavior_specs.keys())[id], action)


try:
    env.close()
except:
    pass

env = UnityEnvironment(file_name="./build/SuikaAI",worker_id=1)
res=run(path="config.txt")
env.close()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.00000 stdev: 0.00000
# Best fitness: 0.00000 - size: (2, 404) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.698, standard deviation 0.290
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     4      0.0    0.000     0
# Total extinctions: 0
# Generation time: 1.327 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.00000 stdev: 0.00000
# Best fitness: 0.00000 - size: (2, 404) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.764, standard deviation 0.338
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     4      0.0    0.000     1
# Total extinctions: 0
# Generation time: 0.613 sec (0.970 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 6.25000 stdev: 10.82532
# Best fitness: 25.00000 - size: (2, 404) - species 1 - id 2
# Average adjusted fitness: 0.250
# Mean genetic distance 0.439, standard deviation 0.277
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     4     25.0    0.250     0
# Total extinctions: 0
# Generation time: 0.920 sec (0.953 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 6.25000 stdev: 10.82532
# Best fitness: 25.00000 - size: (2, 404) - species 1 - id 2
# Average adjusted fitness: 0.250
# Mean genetic distance 0.542, standard deviation 0.244
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     4     25.0    0.250     1
# Total extinctions: 0
# Generation time: 0.919 sec (0.945 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 12.50000 stdev: 12.50000
# Best fitness: 25.00000 - size: (2, 402) - species 1 - id 11
# Average adjusted fitness: 0.500
# Mean genetic distance 0.634, standard deviation 0.099
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     4     25.0    0.500     2
# Total extinctions: 0
# Generation time: 0.915 sec (0.939 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 50.00000 stdev: 0.00000
# Best fitness: 50.00000 - size: (2, 402) - species 1 - id 11
# Average adjusted fitness: 0.000
# Mean genetic distance 0.309, standard deviation 0.182
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     4     50.0    0.000     0
# Total extinctions: 0
# Generation time: 1.506 sec (1.033 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 43.75000 stdev: 10.82532
# Best fitness: 50.00000 - size: (2, 403) - species 1 - id 12
# Average adjusted fitness: 0.750
# Mean genetic distance 0.394, standard deviation 0.207
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     4     50.0    0.750     1
# Total extinctions: 0
# Generation time: 1.534 sec (1.105 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 81.25000 stdev: 20.72890
# Best fitness: 100.00000 - size: (2, 403) - species 1 - id 12
# Average adjusted fitness: 0.625
# Mean genetic distance 0.465, standard deviation 0.194
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     4    100.0    0.625     0
# Total extinctions: 0
# Generation time: 1.816 sec (1.194 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 93.75000 stdev: 20.72890
# Best fitness: 125.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.375
# Mean genetic distance 0.403, standard deviation 0.169
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     4    125.0    0.375     0
# Total extinctions: 0
# Generation time: 2.122 sec (1.297 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 75.00000 stdev: 17.67767
# Best fitness: 100.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.500
# Mean genetic distance 0.495, standard deviation 0.210
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     4    100.0    0.500     1
# Total extinctions: 0
# Generation time: 1.532 sec (1.320 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 112.50000 stdev: 12.50000
# Best fitness: 125.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.500
# Mean genetic distance 0.469, standard deviation 0.219
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10     4    125.0    0.500     2
# Total extinctions: 0
# Generation time: 2.109 sec (1.399 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 106.25000 stdev: 20.72890
# Best fitness: 125.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.625
# Mean genetic distance 0.700, standard deviation 0.116
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11     4    125.0    0.625     3
# Total extinctions: 0
# Generation time: 2.120 sec (1.549 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 143.75000 stdev: 10.82532
# Best fitness: 150.00000 - size: (2, 401) - species 1 - id 26
# Average adjusted fitness: 0.750
# Mean genetic distance 0.745, standard deviation 0.330
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12     4    150.0    0.750     0
# Total extinctions: 0
# Generation time: 2.712 sec (1.729 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 118.75000 stdev: 40.98399
# Best fitness: 150.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.688
# Mean genetic distance 0.522, standard deviation 0.281
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13     4    150.0    0.688     1
# Total extinctions: 0
# Generation time: 2.731 sec (1.910 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 112.50000 stdev: 21.65064
# Best fitness: 150.00000 - size: (3, 401) - species 1 - id 32
# Average adjusted fitness: 0.250
# Mean genetic distance 0.648, standard deviation 0.306
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14     4    150.0    0.250     2
# Total extinctions: 0
# Generation time: 2.715 sec (2.090 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 193.75000 stdev: 10.82532
# Best fitness: 200.00000 - size: (2, 401) - species 1 - id 20
# Average adjusted fitness: 0.750
# Mean genetic distance 0.701, standard deviation 0.399
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     4    200.0    0.750     0
# Total extinctions: 0
# Generation time: 3.014 sec (2.241 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 175.00000 stdev: 43.30127
# Best fitness: 200.00000 - size: (4, 400) - species 1 - id 33
# Average adjusted fitness: 0.750
# Mean genetic distance 0.855, standard deviation 0.263
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     4    200.0    0.750     1
# Total extinctions: 0
# Generation time: 3.036 sec (2.391 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 232.00000 stdev: 10.46422
# Best fitness: 250.00000 - size: (2, 399) - species 1 - id 38
# Average adjusted fitness: 0.280
# Mean genetic distance 0.748, standard deviation 0.283
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     4    250.0    0.280     0
# Total extinctions: 0
# Generation time: 3.312 sec (2.540 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 232.75000 stdev: 32.22092
# Best fitness: 275.00000 - size: (4, 400) - species 1 - id 33
# Average adjusted fitness: 0.437
# Mean genetic distance 1.018, standard deviation 0.171
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     4    275.0    0.437     0
# Total extinctions: 0
# Generation time: 3.320 sec (2.660 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 175.75000 stdev: 110.74379
# Best fitness: 300.00000 - size: (2, 394) - species 1 - id 40
# Average adjusted fitness: 0.586
# Mean genetic distance 0.557, standard deviation 0.297
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     4    300.0    0.586     0
# Total extinctions: 0
# Generation time: 3.313 sec (2.838 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 254.75000 stdev: 8.22724
# Best fitness: 269.00000 - size: (2, 394) - species 1 - id 40
# Average adjusted fitness: 0.250
# Mean genetic distance 0.792, standard deviation 0.368
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     4    269.0    0.250     1
# Total extinctions: 0
# Generation time: 3.932 sec (3.021 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 207.75000 stdev: 135.57355
# Best fitness: 375.00000 - size: (5, 398) - species 1 - id 46
# Average adjusted fitness: 0.554
# Mean genetic distance 1.015, standard deviation 0.430
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     4    375.0    0.554     0
# Total extinctions: 0
# Generation time: 3.916 sec (3.200 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 212.50000 stdev: 124.37343
# Best fitness: 300.00000 - size: (6, 399) - species 1 - id 47
# Average adjusted fitness: 0.708
# Mean genetic distance 1.152, standard deviation 0.163
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     4    300.0    0.708     1
# Total extinctions: 0
# Generation time: 4.218 sec (3.351 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 263.75000 stdev: 158.40514
# Best fitness: 420.00000 - size: (5, 394) - species 1 - id 48
# Average adjusted fitness: 0.628
# Mean genetic distance 0.746, standard deviation 0.374
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     4    420.0    0.628     0
# Total extinctions: 0
# Generation time: 4.225 sec (3.500 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 321.00000 stdev: 22.39420
# Best fitness: 353.00000 - size: (5, 388) - species 1 - id 52
# Average adjusted fitness: 0.396
# Mean genetic distance 0.946, standard deviation 0.317
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     4    353.0    0.396     1
# Total extinctions: 0
# Generation time: 4.210 sec (3.650 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 382.25000 stdev: 65.67106
# Best fitness: 485.00000 - size: (6, 387) - species 1 - id 53
# Average adjusted fitness: 0.358
# Mean genetic distance 0.487, standard deviation 0.237
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25     4    485.0    0.358     0
# Total extinctions: 0
# Generation time: 4.518 sec (3.800 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 404.00000 stdev: 61.42475
# Best fitness: 491.00000 - size: (6, 385) - species 1 - id 56
# Average adjusted fitness: 0.476
# Mean genetic distance 0.597, standard deviation 0.165
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26     4    491.0    0.476     0
# Total extinctions: 0
# Generation time: 4.527 sec (3.949 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 405.75000 stdev: 91.07243
# Best fitness: 560.00000 - size: (6, 385) - species 1 - id 56
# Average adjusted fitness: 0.344
# Mean genetic distance 0.591, standard deviation 0.223
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27     4    560.0    0.344     0
# Total extinctions: 0
# Generation time: 5.112 sec (4.129 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 441.50000 stdev: 45.13037
# Best fitness: 519.00000 - size: (6, 385) - species 1 - id 56
# Average adjusted fitness: 0.295
# Mean genetic distance 0.354, standard deviation 0.150
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28     4    519.0    0.295     1
# Total extinctions: 0
# Generation time: 5.131 sec (4.310 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 418.25000 stdev: 66.38665
# Best fitness: 494.00000 - size: (6, 385) - species 1 - id 61
# Average adjusted fitness: 0.552
# Mean genetic distance 0.550, standard deviation 0.292
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29     4    494.0    0.552     2
# Total extinctions: 0
# Generation time: 5.117 sec (4.491 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 522.50000 stdev: 121.19097
# Best fitness: 653.00000 - size: (6, 379) - species 1 - id 63
# Average adjusted fitness: 0.484
# Mean genetic distance 0.808, standard deviation 0.215
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30     4    653.0    0.484     0
# Total extinctions: 0
# Generation time: 5.411 sec (4.638 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 499.75000 stdev: 135.93082
# Best fitness: 734.00000 - size: (6, 379) - species 1 - id 63
# Average adjusted fitness: 0.299
# Mean genetic distance 0.735, standard deviation 0.320
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31     4    734.0    0.299     0
# Total extinctions: 0
# Generation time: 5.434 sec (4.790 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 446.25000 stdev: 13.10296
# Best fitness: 460.00000 - size: (6, 378) - species 1 - id 68
# Average adjusted fitness: 0.607
# Mean genetic distance 1.045, standard deviation 0.222
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     4    460.0    0.607     1
# Total extinctions: 0
# Generation time: 5.715 sec (4.940 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 493.00000 stdev: 56.28943
# Best fitness: 553.00000 - size: (6, 377) - species 1 - id 69
# Average adjusted fitness: 0.531
# Mean genetic distance 1.195, standard deviation 0.293
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     4    553.0    0.531     2
# Total extinctions: 0
# Generation time: 5.712 sec (5.089 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 482.25000 stdev: 59.61281
# Best fitness: 563.00000 - size: (6, 377) - species 1 - id 69
# Average adjusted fitness: 0.415
# Mean genetic distance 0.899, standard deviation 0.372
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     4    563.0    0.415     3
# Total extinctions: 0
# Generation time: 5.734 sec (5.241 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 436.00000 stdev: 263.63896
# Best fitness: 675.00000 - size: (6, 371) - species 1 - id 74
# Average adjusted fitness: 0.646
# Mean genetic distance 0.850, standard deviation 0.356
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35     4    675.0    0.646     4
# Total extinctions: 0
# Generation time: 6.307 sec (5.420 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 491.00000 stdev: 16.52271
# Best fitness: 512.00000 - size: (6, 373) - species 1 - id 75
# Average adjusted fitness: 0.543
# Mean genetic distance 0.956, standard deviation 0.203
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     4    512.0    0.543     5
# Total extinctions: 0
# Generation time: 6.332 sec (5.601 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 564.25000 stdev: 75.65836
# Best fitness: 685.00000 - size: (5, 370) - species 1 - id 78
# Average adjusted fitness: 0.347
# Mean genetic distance 0.839, standard deviation 0.307
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     4    685.0    0.347     6
# Total extinctions: 0
# Generation time: 6.609 sec (5.750 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 574.50000 stdev: 54.61456
# Best fitness: 669.00000 - size: (5, 372) - species 1 - id 76
# Average adjusted fitness: 0.262
# Mean genetic distance 0.798, standard deviation 0.232
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     4    669.0    0.262     7
# Total extinctions: 0
# Generation time: 6.623 sec (5.900 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 629.25000 stdev: 63.74706
# Best fitness: 700.00000 - size: (5, 365) - species 1 - id 81
# Average adjusted fitness: 0.538
# Mean genetic distance 1.110, standard deviation 0.388
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     4    700.0    0.538     8
# Total extinctions: 0
# Generation time: 6.620 sec (6.050 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 606.50000 stdev: 62.96229
# Best fitness: 701.00000 - size: (5, 370) - species 1 - id 84
# Average adjusted fitness: 0.463
# Mean genetic distance 1.141, standard deviation 0.560
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40     4    701.0    0.463     9
# Total extinctions: 0
# Generation time: 6.917 sec (6.200 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 640.75000 stdev: 67.06107
# Best fitness: 753.00000 - size: (5, 368) - species 1 - id 86
# Average adjusted fitness: 0.332
# Mean genetic distance 0.465, standard deviation 0.201
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     4    753.0    0.332     0
# Total extinctions: 0
# Generation time: 6.925 sec (6.349 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 666.00000 stdev: 83.71977
# Best fitness: 769.00000 - size: (5, 371) - species 1 - id 82
# Average adjusted fitness: 0.523
# Mean genetic distance 0.487, standard deviation 0.201
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     4    769.0    0.523     0
# Total extinctions: 0
# Generation time: 7.514 sec (6.529 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 678.25000 stdev: 163.66792
# Best fitness: 956.00000 - size: (5, 368) - species 1 - id 86
# Average adjusted fitness: 0.316
# Mean genetic distance 0.583, standard deviation 0.115
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     4    956.0    0.316     0
# Total extinctions: 0
# Generation time: 7.530 sec (6.711 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 626.75000 stdev: 87.74216
# Best fitness: 776.00000 - size: (5, 368) - species 1 - id 86
# Average adjusted fitness: 0.340
# Mean genetic distance 0.702, standard deviation 0.219
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44     4    776.0    0.340     1
# Total extinctions: 0
# Generation time: 7.514 sec (6.889 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 798.00000 stdev: 109.15814
# Best fitness: 929.00000 - size: (5, 367) - species 1 - id 94
# Average adjusted fitness: 0.565
# Mean genetic distance 0.603, standard deviation 0.300
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45     4    929.0    0.565     2
# Total extinctions: 0
# Generation time: 7.822 sec (7.041 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 869.25000 stdev: 71.20876
# Best fitness: 982.00000 - size: (5, 366) - species 1 - id 96
# Average adjusted fitness: 0.377
# Mean genetic distance 0.710, standard deviation 0.107
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46     4    982.0    0.377     0
# Total extinctions: 0
# Generation time: 7.815 sec (7.189 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 713.25000 stdev: 98.38286
# Best fitness: 863.00000 - size: (5, 363) - species 1 - id 98
# Average adjusted fitness: 0.371
# Mean genetic distance 0.851, standard deviation 0.143
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47     4    863.0    0.371     1
# Total extinctions: 0
# Generation time: 8.111 sec (7.339 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 884.50000 stdev: 226.44481
# Best fitness: 1132.00000 - size: (5, 363) - species 1 - id 97
# Average adjusted fitness: 0.512
# Mean genetic distance 0.887, standard deviation 0.129
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48     4   1132.0    0.512     0
# Total extinctions: 0
# Generation time: 8.130 sec (7.490 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 856.50000 stdev: 80.46894
# Best fitness: 975.00000 - size: (5, 362) - species 1 - id 99
# Average adjusted fitness: 0.416
# Mean genetic distance 0.957, standard deviation 0.403
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49     4    975.0    0.416     1
# Total extinctions: 0
# Generation time: 8.113 sec (7.639 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 394.75000 stdev: 406.88781
# Best fitness: 929.00000 - size: (5, 360) - species 1 - id 101
# Average adjusted fitness: 0.425
# Mean genetic distance 0.698, standard deviation 0.331
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50     4    929.0    0.425     2
# Total extinctions: 0
# Generation time: 8.733 sec (7.821 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 1010.50000 stdev: 237.71990
# Best fitness: 1335.00000 - size: (5, 358) - species 1 - id 106
# Average adjusted fitness: 0.423
# Mean genetic distance 0.573, standard deviation 0.247
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51     4   1335.0    0.423     0
# Total extinctions: 0
# Generation time: 8.717 sec (8.000 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 930.25000 stdev: 137.87562
# Best fitness: 1063.00000 - size: (5, 362) - species 1 - id 99
# Average adjusted fitness: 0.634
# Mean genetic distance 0.533, standard deviation 0.229
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52     4   1063.0    0.634     1
# Total extinctions: 0
# Generation time: 9.016 sec (8.150 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 909.50000 stdev: 200.82891
# Best fitness: 1200.00000 - size: (5, 358) - species 1 - id 106
# Average adjusted fitness: 0.419
# Mean genetic distance 0.709, standard deviation 0.230
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53     4   1200.0    0.419     2
# Total extinctions: 0
# Generation time: 9.021 sec (8.299 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 1084.25000 stdev: 270.94684
# Best fitness: 1466.00000 - size: (5, 357) - species 1 - id 109
# Average adjusted fitness: 0.502
# Mean genetic distance 0.717, standard deviation 0.202
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54     4   1466.0    0.502     0
# Total extinctions: 0
# Generation time: 9.029 sec (8.451 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 891.00000 stdev: 151.56682
# Best fitness: 1047.00000 - size: (5, 357) - species 1 - id 114
# Average adjusted fitness: 0.500
# Mean genetic distance 1.036, standard deviation 0.137
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55     4   1047.0    0.500     1
# Total extinctions: 0
# Generation time: 9.301 sec (8.599 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 883.75000 stdev: 264.02213
# Best fitness: 1341.00000 - size: (6, 359) - species 1 - id 113
# Average adjusted fitness: 0.258
# Mean genetic distance 0.721, standard deviation 0.389
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56     4   1341.0    0.258     2
# Total extinctions: 0
# Generation time: 9.332 sec (8.750 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 1013.50000 stdev: 165.70229
# Best fitness: 1175.00000 - size: (6, 359) - species 1 - id 113
# Average adjusted fitness: 0.620
# Mean genetic distance 0.591, standard deviation 0.246
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57     4   1175.0    0.620     3
# Total extinctions: 0
# Generation time: 9.907 sec (8.930 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 999.75000 stdev: 165.99002
# Best fitness: 1185.00000 - size: (6, 356) - species 1 - id 119
# Average adjusted fitness: 0.564
# Mean genetic distance 0.838, standard deviation 0.297
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58     4   1185.0    0.564     4
# Total extinctions: 0
# Generation time: 9.933 sec (9.110 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 707.00000 stdev: 425.04647
# Best fitness: 1055.00000 - size: (7, 357) - species 1 - id 121
# Average adjusted fitness: 0.670
# Mean genetic distance 1.033, standard deviation 0.163
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59     4   1055.0    0.670     5
# Total extinctions: 0
# Generation time: 9.955 sec (9.294 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 875.75000 stdev: 586.52637
# Best fitness: 1626.00000 - size: (8, 357) - species 1 - id 123
# Average adjusted fitness: 0.539
# Mean genetic distance 0.775, standard deviation 0.199
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60     4   1626.0    0.539     0
# Total extinctions: 0
# Generation time: 10.187 sec (9.440 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 906.00000 stdev: 183.59739
# Best fitness: 1224.00000 - size: (7, 357) - species 1 - id 121
# Average adjusted fitness: 0.250
# Mean genetic distance 0.748, standard deviation 0.316
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61     4   1224.0    0.250     1
# Total extinctions: 0
# Generation time: 10.222 sec (9.590 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 1108.75000 stdev: 166.82382
# Best fitness: 1249.00000 - size: (7, 355) - species 1 - id 127
# Average adjusted fitness: 0.669
# Mean genetic distance 0.577, standard deviation 0.296
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62     4   1249.0    0.669     2
# Total extinctions: 0
# Generation time: 10.511 sec (9.740 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 1185.75000 stdev: 150.19883
# Best fitness: 1399.00000 - size: (8, 357) - species 1 - id 129
# Average adjusted fitness: 0.464
# Mean genetic distance 0.759, standard deviation 0.275
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63     4   1399.0    0.464     3
# Total extinctions: 0
# Generation time: 10.532 sec (9.891 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 860.75000 stdev: 501.26708
# Best fitness: 1250.00000 - size: (7, 353) - species 1 - id 131
# Average adjusted fitness: 0.689
# Mean genetic distance 0.775, standard deviation 0.483
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64     4   1250.0    0.689     4
# Total extinctions: 0
# Generation time: 10.510 sec (10.039 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 1334.25000 stdev: 45.52129
# Best fitness: 1406.00000 - size: (8, 355) - species 1 - id 133
# Average adjusted fitness: 0.421
# Mean genetic distance 1.010, standard deviation 0.401
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65     4   1406.0    0.421     5
# Total extinctions: 0
# Generation time: 11.128 sec (10.222 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 1393.25000 stdev: 195.60851
# Best fitness: 1641.00000 - size: (8, 349) - species 1 - id 136
# Average adjusted fitness: 0.513
# Mean genetic distance 1.182, standard deviation 0.296
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66     4   1641.0    0.513     0
# Total extinctions: 0
# Generation time: 11.109 sec (10.399 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 1188.25000 stdev: 154.52730
# Best fitness: 1395.00000 - size: (8, 354) - species 1 - id 135
# Average adjusted fitness: 0.521
# Mean genetic distance 0.971, standard deviation 0.273
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67     4   1395.0    0.521     1
# Total extinctions: 0
# Generation time: 11.430 sec (10.552 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 1212.00000 stdev: 271.15033
# Best fitness: 1625.00000 - size: (7, 346) - species 1 - id 138
# Average adjusted fitness: 0.394
# Mean genetic distance 0.622, standard deviation 0.261
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68     4   1625.0    0.394     2
# Total extinctions: 0
# Generation time: 11.405 sec (10.699 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 1078.25000 stdev: 624.41147
# Best fitness: 1493.00000 - size: (8, 350) - species 1 - id 141
# Average adjusted fitness: 0.722
# Mean genetic distance 0.964, standard deviation 0.152
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69     4   1493.0    0.722     3
# Total extinctions: 0
# Generation time: 11.433 sec (10.847 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 1615.25000 stdev: 386.95437
# Best fitness: 2070.00000 - size: (8, 350) - species 1 - id 141
# Average adjusted fitness: 0.571
# Mean genetic distance 0.914, standard deviation 0.315
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70     4   2070.0    0.571     0
# Total extinctions: 0
# Generation time: 11.724 sec (11.000 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 1790.50000 stdev: 422.51302
# Best fitness: 2291.00000 - size: (8, 347) - species 1 - id 145
# Average adjusted fitness: 0.488
# Mean genetic distance 0.892, standard deviation 0.191
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71     4   2291.0    0.488     0
# Total extinctions: 0
# Generation time: 11.713 sec (11.149 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 1515.50000 stdev: 203.63018
# Best fitness: 1797.00000 - size: (8, 345) - species 1 - id 147
# Average adjusted fitness: 0.506
# Mean genetic distance 1.022, standard deviation 0.273
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72     4   1797.0    0.506     1
# Total extinctions: 0
# Generation time: 12.328 sec (11.331 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 1425.00000 stdev: 266.75738
# Best fitness: 1750.00000 - size: (8, 345) - species 1 - id 149
# Average adjusted fitness: 0.561
# Mean genetic distance 0.830, standard deviation 0.167
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73     4   1750.0    0.561     2
# Total extinctions: 0
# Generation time: 12.305 sec (11.508 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 1521.50000 stdev: 130.02404
# Best fitness: 1687.00000 - size: (8, 345) - species 1 - id 149
# Average adjusted fitness: 0.509
# Mean genetic distance 0.745, standard deviation 0.311
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   74     4   1687.0    0.509     3
# Total extinctions: 0
# Generation time: 12.324 sec (11.690 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 1522.50000 stdev: 366.07684
# Best fitness: 1987.00000 - size: (8, 345) - species 1 - id 147
# Average adjusted fitness: 0.527
# Mean genetic distance 0.661, standard deviation 0.373
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   75     4   1987.0    0.527     4
# Total extinctions: 0
# Generation time: 12.631 sec (11.840 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 1537.25000 stdev: 301.96968
# Best fitness: 1964.00000 - size: (8, 346) - species 1 - id 155
# Average adjusted fitness: 0.500
# Mean genetic distance 0.589, standard deviation 0.218
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   76     4   1964.0    0.500     5
# Total extinctions: 0
# Generation time: 12.610 sec (11.990 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 1985.25000 stdev: 397.53074
# Best fitness: 2650.00000 - size: (8, 343) - species 1 - id 157
# Average adjusted fitness: 0.357
# Mean genetic distance 0.385, standard deviation 0.227
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   77     4   2650.0    0.357     0
# Total extinctions: 0
# Generation time: 12.927 sec (12.140 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 1629.50000 stdev: 377.37548
# Best fitness: 2062.00000 - size: (8, 346) - species 1 - id 155
# Average adjusted fitness: 0.583
# Mean genetic distance 0.514, standard deviation 0.326
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   78     4   2062.0    0.583     1
# Total extinctions: 0
# Generation time: 12.907 sec (12.290 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 1700.25000 stdev: 330.46208
# Best fitness: 2094.00000 - size: (8, 346) - species 1 - id 155
# Average adjusted fitness: 0.481
# Mean genetic distance 0.413, standard deviation 0.172
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   79     4   2094.0    0.481     2
# Total extinctions: 0
# Generation time: 12.932 sec (12.440 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 1635.75000 stdev: 236.02370
# Best fitness: 1860.00000 - size: (8, 345) - species 1 - id 163
# Average adjusted fitness: 0.638
# Mean genetic distance 0.578, standard deviation 0.084
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   80     4   1860.0    0.638     3
# Total extinctions: 0
# Generation time: 13.523 sec (12.620 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 1181.25000 stdev: 684.57044
# Best fitness: 1645.00000 - size: (8, 346) - species 1 - id 166
# Average adjusted fitness: 0.718
# Mean genetic distance 0.690, standard deviation 0.094
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   81     4   1645.0    0.718     4
# Total extinctions: 0
# Generation time: 13.513 sec (12.800 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 1757.25000 stdev: 382.40971
# Best fitness: 2129.00000 - size: (8, 347) - species 1 - id 168
# Average adjusted fitness: 0.621
# Mean genetic distance 0.677, standard deviation 0.298
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   82     4   2129.0    0.621     5
# Total extinctions: 0
# Generation time: 13.823 sec (12.950 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 1964.50000 stdev: 551.76195
# Best fitness: 2551.00000 - size: (8, 344) - species 1 - id 169
# Average adjusted fitness: 0.596
# Mean genetic distance 0.837, standard deviation 0.238
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   83     4   2551.0    0.596     6
# Total extinctions: 0
# Generation time: 13.825 sec (13.102 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 1499.25000 stdev: 401.96852
# Best fitness: 1991.00000 - size: (8, 344) - species 1 - id 169
# Average adjusted fitness: 0.448
# Mean genetic distance 0.422, standard deviation 0.183
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   84     4   1991.0    0.448     7
# Total extinctions: 0
# Generation time: 13.803 sec (13.249 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 1739.25000 stdev: 434.14650
# Best fitness: 2285.00000 - size: (8, 347) - species 1 - id 168
# Average adjusted fitness: 0.530
# Mean genetic distance 0.583, standard deviation 0.259
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   85     4   2285.0    0.530     8
# Total extinctions: 0
# Generation time: 14.126 sec (13.399 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: 1849.25000 stdev: 109.87806
# Best fitness: 2001.00000 - size: (8, 344) - species 1 - id 174
# Average adjusted fitness: 0.507
# Mean genetic distance 0.828, standard deviation 0.165
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   86     4   2001.0    0.507     9
# Total extinctions: 0
# Generation time: 14.124 sec (13.550 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 1215.25000 stdev: 895.50192
# Best fitness: 2529.00000 - size: (8, 344) - species 1 - id 174
# Average adjusted fitness: 0.481
# Mean genetic distance 0.718, standard deviation 0.295
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   87     4   2529.0    0.481    10
# Total extinctions: 0
# Generation time: 14.710 sec (13.729 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 1664.50000 stdev: 284.42618
# Best fitness: 1950.00000 - size: (8, 341) - species 1 - id 175
# Average adjusted fitness: 0.618
# Mean genetic distance 0.745, standard deviation 0.210
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   88     4   1950.0    0.618    11
# Total extinctions: 0
# Generation time: 14.735 sec (13.911 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 1374.25000 stdev: 323.67605
# Best fitness: 1931.00000 - size: (8, 341) - species 1 - id 175
# Average adjusted fitness: 0.287
# Mean genetic distance 0.515, standard deviation 0.226
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   89     4   1931.0    0.287    12
# Total extinctions: 0
# Generation time: 14.722 sec (14.090 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 1709.50000 stdev: 527.06949
# Best fitness: 2497.00000 - size: (8, 339) - species 1 - id 181
# Average adjusted fitness: 0.393
# Mean genetic distance 0.504, standard deviation 0.215
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   90     4   2497.0    0.393    13
# Total extinctions: 0
# Generation time: 15.011 sec (14.239 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 2202.50000 stdev: 307.15916
# Best fitness: 2691.00000 - size: (8, 338) - species 1 - id 186
# Average adjusted fitness: 0.394
# Mean genetic distance 0.816, standard deviation 0.186
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   91     4   2691.0    0.394     0
# Total extinctions: 0
# Generation time: 15.022 sec (14.390 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 1709.50000 stdev: 356.76218
# Best fitness: 2096.00000 - size: (8, 338) - species 1 - id 186
# Average adjusted fitness: 0.488
# Mean genetic distance 0.517, standard deviation 0.260
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   92     4   2096.0    0.488     1
# Total extinctions: 0
# Generation time: 18.054 sec (14.813 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 1573.50000 stdev: 331.88741
# Best fitness: 1934.00000 - size: (8, 338) - species 1 - id 186
# Average adjusted fitness: 0.492
# Mean genetic distance 0.766, standard deviation 0.358
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   93     4   1934.0    0.492     2
# Total extinctions: 0
# Generation time: 15.324 sec (14.963 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 1753.50000 stdev: 518.41369
# Best fitness: 2451.00000 - size: (7, 329) - species 1 - id 191
# Average adjusted fitness: 0.431
# Mean genetic distance 0.668, standard deviation 0.280
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   94     4   2451.0    0.431     3
# Total extinctions: 0
# Generation time: 15.330 sec (15.116 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 2276.00000 stdev: 30.20761
# Best fitness: 2302.00000 - size: (8, 327) - species 1 - id 194
# Average adjusted fitness: 0.662
# Mean genetic distance 1.034, standard deviation 0.164
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   95     4   2302.0    0.662     4
# Total extinctions: 0
# Generation time: 15.918 sec (15.295 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 2219.25000 stdev: 402.12957
# Best fitness: 2869.00000 - size: (8, 337) - species 1 - id 193
# Average adjusted fitness: 0.364
# Mean genetic distance 0.880, standard deviation 0.381
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   96     4   2869.0    0.364     0
# Total extinctions: 0
# Generation time: 15.910 sec (15.473 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 2023.75000 stdev: 342.96237
# Best fitness: 2413.00000 - size: (9, 333) - species 1 - id 198
# Average adjusted fitness: 0.528
# Mean genetic distance 0.990, standard deviation 0.240
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   97     4   2413.0    0.528     1
# Total extinctions: 0
# Generation time: 16.235 sec (15.626 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 2125.25000 stdev: 395.14198
# Best fitness: 2441.00000 - size: (9, 331) - species 1 - id 200
# Average adjusted fitness: 0.678
# Mean genetic distance 1.183, standard deviation 0.288
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   98     4   2441.0    0.678     2
# Total extinctions: 0
# Generation time: 16.220 sec (15.774 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 877.50000 stdev: 932.21175
# Best fitness: 2200.00000 - size: (9, 335) - species 1 - id 199
# Average adjusted fitness: 0.399
# Mean genetic distance 1.011, standard deviation 0.565
# Population of 4 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   99     4   2200.0    0.399     3
# Total extinctions: 0
# Generation time: 16.210 sec (15.923 average)

# %%
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 env.close()
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\environment.py:425, in UnityEnvironment.close(self)
#     421 """
#     422 Sends a shutdown signal to the unity environment, and closes the socket connection.
#     423 """
#     424 if self._loaded:
# --> 425     self._close()
#     426 else:
#     427     raise UnityEnvironmentException("No Unity environment is loaded.")
#
# File c:\Users\shirles\Documents\perso\IA\AI_SUIKA\.venv\lib\site-packages\mlagents_envs\environment.py:443, in UnityEnvironment._close(self, timeout)
#     440 if self._process is not None:
#     441     # Wait a bit for the process to shutdown, but kill it if it takes too long
#     442     try:
# --> 443         self._process.wait(timeout=timeout)
#     444         logger.debug(self._returncode_to_env_message(self._process.returncode))
#     445     except subprocess.TimeoutExpired:
#
# File C:\Python310\lib\subprocess.py:1207, in Popen.wait(self, timeout)
#    1205     endtime = _time() + timeout
#    1206 try:
# -> 1207     return self._wait(timeout=timeout)
#    1208 except KeyboardInterrupt:
#    1209     # https://bugs.python.org/issue25942
#    1210     # The first keyboard interrupt waits briefly for the child to
#    1211     # exit under the common assumption that it also received the ^C
#    1212     # generated SIGINT and will exit rapidly.
#    1213     if timeout is not None:
#
# File C:\Python310\lib\subprocess.py:1488, in Popen._wait(self, timeout)
#    1485     timeout_millis = int(timeout * 1000)
#    1486 if self.returncode is None:
#    1487     # API note: Returns immediately if timeout_millis == 0.
# -> 1488     result = _winapi.WaitForSingleObject(self._handle,
#    1489                                          timeout_millis)
#    1490     if result == _winapi.WAIT_TIMEOUT:
#    1491         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:
